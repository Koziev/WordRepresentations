# %%
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv(r'e:\polygon\WordRepresentations\data\autoencoder_losses.csv')
df['val_tags_loss*10'] = df.val_tags_loss*10

# %%
df1 = df[ ['val_word_loss','val_tags_loss*10','val_w2v_loss'] ]
plt.figure(); df1.plot();
